# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\saran\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\saran\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\saran\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\saran\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\saran\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\saran\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus = """ Hello welcome, My name is saravanan and i am a datascience student.
I don't know anything about NLP."""

# %%
print(corpus)
# Out:
#  Hello welcome, My name is saravanan and i am a datascience student.
# I don't know anything about NLP.

# %%
### Tokenization 
### paragraph --> sentence 
import nltk
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\saran\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents = sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello welcome, My name is saravanan and i am a datascience student.
# I don't know anything about NLP.

# %%
### Tokenization 
### sentence ---> words
### paragraph --> words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'saravanan',
#  'and',
#  'i',
#  'am',
#  'a',
#  'datascience',
#  'student',
#  '.',
#  'I',
#  'do',
#  "n't",
#  'know',
#  'anything',
#  'about',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'My', 'name', 'is', 'saravanan', 'and', 'i', 'am', 'a', 'datascience', 'student', '.']
# ['I', 'do', "n't", 'know', 'anything', 'about', 'NLP', '.']

# %%
### Defines punctuation 

from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'saravanan',
#  'and',
#  'i',
#  'am',
#  'a',
#  'datascience',
#  'student',
#  '.',
#  'I',
#  'don',
#  "'",
#  't',
#  'know',
#  'anything',
#  'about',
#  'NLP',
#  '.']

# %%
### TreeBank 

from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'saravanan',
#  'and',
#  'i',
#  'am',
#  'a',
#  'datascience',
#  'student.',
#  'I',
#  'do',
#  "n't",
#  'know',
#  'anything',
#  'about',
#  'NLP',
#  '.']
